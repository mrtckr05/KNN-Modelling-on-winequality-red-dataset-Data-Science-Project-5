# %% [markdown]
# # KNN Modelling on winequality-red dataset

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization purposes
import seaborn as sns # for data visualization
import altair as alt
# %matplotlib inline
import os

# %% [markdown]
# ## Simple statistical investigation :
# - Read the dataset and investigate it.
# - The dataset should be copied over into your working folder.

# %%
redwine = pd.read_csv('winequality-red.csv', sep=';', header = 'infer') # Datafile has to be in your working folder.

# %%
redwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redwine.mean()
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.636023
# dtype: float64

# %%
redwine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
redwine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Data Visualization :
# Using librraies like seaborn, matplotlib, pandas and altair packages please apply data visualizations:
# - Scatterplot
# - Barplot
# - Histogram
# - Heatmap
# <br>
#   - Plotting Boxplot of quality againts one or more features. (eg. quality vs 'alcohol' or 'volatile acidity')

# %%
fig,axes = plt.subplots(nrows=3,ncols=4,figsize=(16,6))

axes[0,0].plot(redwine['fixed acidity'],redwine['quality'],'o')
axes[0,0].set_ylabel("quality")

axes[0,1].plot(redwine['volatile acidity'],redwine['quality'],'o')
axes[0,1].set_ylabel("quality")

axes[0,2].plot(redwine['citric acid'],redwine['quality'],'o')
axes[0,2].set_ylabel("quality")

axes[0,3].plot(redwine['residual sugar'],redwine['quality'],'o')
axes[0,3].set_ylabel("quality")

axes[1,0].plot(redwine['chlorides'],redwine['quality'],'o')
axes[1,0].set_ylabel("quality")

axes[1,1].plot(redwine['free sulfur dioxide'],redwine['quality'],'o')
axes[1,1].set_ylabel("quality")

axes[1,2].plot(redwine['total sulfur dioxide'],redwine['quality'],'o')
axes[1,2].set_ylabel("quality")

axes[1,3].plot(redwine['density'],redwine['quality'],'o')
axes[1,3].set_ylabel("quality")

axes[2,0].plot(redwine['pH'],redwine['quality'],'o')
axes[2,0].set_ylabel("quality")

axes[2,1].plot(redwine['sulphates'],redwine['quality'],'o')
axes[2,1].set_ylabel("quality")

axes[2,2].plot(redwine['alcohol'],redwine['quality'],'o')
axes[2,2].set_ylabel("quality")
    
axes[0,0].set_title("fixed acidity-quality")
axes[0,1].set_title("volatile acidity-quality")
axes[0,2].set_title("citric acid-quality")
axes[0,3].set_title("residual sugar-quality")
axes[1,0].set_title("chlorides-quality")
axes[1,1].set_title("free sulfur dioxide-quality")
axes[1,2].set_title("total sulfur dioxide-quality") 
axes[1,3].set_title("density-quality")
axes[2,0].set_title("pH-quality")
axes[2,1].set_title("sulphates-quality")                      
axes[2,2].set_title("alcohol-quality")

                     
plt.tight_layout();

# %%
sns.set(style="whitegrid")
#fixed acidity	volatile acidity	citric acid	residual sugar	chlorides	free sulfur dioxide	total sulfur dioxide	density	pH	sulphates	alcohol	quality
fig, axes = plt.subplots(3, 4, figsize=(14, 10))

sns.histplot(redwine['fixed acidity'], kde=True, ax=axes[0, 0]).set(title="fixed acidity Distribution")

sns.histplot(redwine['volatile acidity'], kde=True, ax=axes[0, 1]).set(title="volatile acidity Distribution")

sns.histplot(redwine['citric acid'], discrete=True, ax=axes[0, 2]).set(title="citric acid Distribution")

sns.histplot(redwine['residual sugar'], kde=True, ax=axes[0, 3]).set(title="residual sugar Distribution")

sns.histplot(redwine['chlorides'], kde=True, ax=axes[1, 0]).set(title="chlorides Distribution")

sns.histplot(redwine['free sulfur dioxide'], kde=True, ax=axes[1, 1]).set(title="free sulfur dioxide Distribution")

sns.histplot(redwine['total sulfur dioxide'], kde=True, ax=axes[1, 2]).set(title="total sulfur dioxide Distribution")

sns.histplot(redwine['density'], kde=True, ax=axes[1, 3]).set(title="density Distribution")

sns.histplot(redwine['pH'], kde=True, ax=axes[2, 0]).set(title="pH Distribution")

sns.histplot(redwine['sulphates'], kde=True, ax=axes[2, 1]).set(title="sulphates Distribution")

sns.histplot(redwine['alcohol'], kde=True, ax=axes[2, 2]).set(title="alcohol Distribution")

sns.histplot(redwine['quality'], kde=True, ax=axes[2, 3]).set(title="quality Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Modelling :
# - Preprocess data:
#   - The target variable is "quality". Convert this variable to so that it will be binary classification: new quantity column will have only the values 0 and 1.
#   - Make train&test split, and fit a KNN model
#   - Evaluate the performance on both training and test sets
#   - Give accuracy, precision, recall and f1 scores on the test set.
#   - Give Confussion Matrix

# %% [markdown]
# #### PreProcessing
# - If the quality value > 5, it means the quality is good and define it as "Good".
# - Otherwise, you can define it as "Bad".
# (Hint: you can use numpy where function to conditionally set the column)

# %% [markdown]
# #### Train & Test Split
# - Use stratify keyword set to class label "quality"

# %%
redwine["quality"]=np.where(redwine["quality"]>5,"Good","Bad")

# %%
redwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
redwine.loc[:,"quality"] == "Good"
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1594    False
# 1595     True
# 1596     True
# 1597    False
# 1598     True
# Name: quality, Length: 1599, dtype: bool

# %%
conditions = [
    redwine['quality']=="Good",
    redwine['quality']=="Bad"
]

# %%
quantity = ['1', '0']

# %%
redwine['quantity'] = np.select(conditions, quantity, default='Unknown')

# %%
redwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# #### KNN model building
# - Fit a KNN model
# - Show the accuracy score for both both training and test cases,
# - Show recall, precision and F1 scores for test cases,
# - Show confusion matrix

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
X = redwine.drop(['quality'], axis=1)
y = redwine['quality']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.7666666666666667
# Precision: 0.7660240705305889
# Recall: 0.7666666666666667
# F1 Score: 0.7656828006519736

# %%
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Parameter Tuning :
# - Apply GridSearchCV
# - Find the best parameters

# %%
knn = KNeighborsClassifier()

param_grid = {'n_neighbors': [1, 3, 5, 7, 9, 11, 12, 13, 14, 15, 16, 17, 18]}
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=10, scoring='accuracy')
grid_search.fit(X_train, y_train)

print("The Best K Value is: ", grid_search.best_params_['n_neighbors'])
print("Accuracy: ", grid_search.best_score_)

best_knn = grid_search.best_estimator_
y_pred = best_knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test Set Accuracy: {accuracy}")
# Out:
# The Best K Value is:  1
# Accuracy:  0.7720881595881595
# Test Set Accuracy: 0.7666666666666667

# %% [markdown]
# ### Apply k-fold Cross Validation:
# -To estimate your final model performance: pick the optimum k parameter you have found through the grid serach, and fit your final KNN model using this k value:
# - To give a relaiable performance report use 10-fold cross validation,
# - Print the classification_report on the final model.

# %%
from sklearn.model_selection import cross_val_score

k_values = range(1, 21)
accuracy_scores = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X_train, y_train, cv=10, scoring='accuracy')
    accuracy_scores.append(scores.mean())

optimal_k = k_values[accuracy_scores.index(max(accuracy_scores))]
print(f"The Best K Value is: {optimal_k} accuracy score is: {max(accuracy_scores)}")
# Out:
# The Best K Value is: 1 accuracy score is: 0.7720881595881595
